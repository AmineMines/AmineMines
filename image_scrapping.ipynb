# %% [markdown]
# <a href="https://colab.research.google.com/github/AmineMines/AmineMines/blob/main/image_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bing_image_downloader import downloader
downloader.download('cat', limit=2,  output_dir='dataset',
adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [%] Downloading Images to /content/dataset/cat
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 2 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/d/d4/Cat_March_2010-1a.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.rd.com/wp-content/uploads/2019/05/4651445a-1.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 2 images.

# %%
# !pip install bing_image_downloader

# %%
import pandas as pd

# %%
chemin_fichier = '/content/Référence_site_web .xlsx'

# Charger le fichier Excel dans un DataFrame
df = pd.read_excel(chemin_fichier)

# %%
for index, row in df.iterrows():
  downloader.download(str(df['Désignation'][index]), limit=2,  output_dir='dataset',
    adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [%] Downloading Images to /content/dataset/PAIN HAMBURGER 1001
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 2 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.mayrand.ca/globalassets/mayrand/catalog-mayrand/epicerie/13991.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://pasquier.qc.ca/img/product/0005657311001_1-Z.JPG
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 2 images.
# [%] Downloading Images to /content/dataset/PAIN HAMBURGER 1002
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 2 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://pasquier.qc.ca/img/product/0005657311001_1-Z.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ytimg.com/vi/3qRSD6MQ7ts/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 2 images.
# [%] Downloading Images to /content/dataset/PAIN HAMBURGER 1003
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 2 Images on Page 1.
#
# ...
#
# ...
